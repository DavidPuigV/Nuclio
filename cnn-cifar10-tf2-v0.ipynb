# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))    # 1 convo
model.add(ks.layers.MaxPooling2D((2, 2)))                 # maxpool

model.add(ks.layers.Flatten())                            # flatten despues convos
model.add(ks.layers.Dense(32, activation='relu'))         # capa dense

model.add(ks.layers.Dense(10, activation='softmax'))      # es clasificacion de 10

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                262176
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 263,402
# Trainable params: 263,402
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 3.1 Definimos callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
callback_para_earlystopping = EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0            # ya cambiamos el escalado a de 0 a 1 para tener numeros reales

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [ # picamos a mano las categorias que sacaremos
'airplane', # id 0
'automobile', # id 1
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck', # id 9
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, epochs=100, callbacks=[callback_para_earlystopping],
                    use_multiprocessing=False, batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 79/79 [==============================] - 4s 16ms/step - loss: 2.1358 - accuracy: 0.2140 - val_loss: 1.7841 - val_accuracy: 0.3613
# Epoch 2/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.6949 - accuracy: 0.4078 - val_loss: 1.5707 - val_accuracy: 0.4468
# Epoch 3/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5151 - accuracy: 0.4674 - val_loss: 1.4828 - val_accuracy: 0.4714
# Epoch 4/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4110 - accuracy: 0.5035 - val_loss: 1.3939 - val_accuracy: 0.5120
# Epoch 5/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3309 - accuracy: 0.5304 - val_loss: 1.3533 - val_accuracy: 0.5221
# Epoch 6/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2824 - accuracy: 0.5467 - val_loss: 1.3163 - val_accuracy: 0.5328
# Epoch 7/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2376 - accuracy: 0.5697 - val_loss: 1.2550 - val_accuracy: 0.5631
# Epoch 8/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1872 - accuracy: 0.5864 - val_loss: 1.2350 - val_accuracy: 0.5674
# Epoch 9/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1497 - accuracy: 0.5980 - val_loss: 1.2106 - val_accuracy: 0.5798
# Epoch 10/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1401 - accuracy: 0.6023 - val_loss: 1.1861 - val_accuracy: 0.5895
# Epoch 11/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0969 - accuracy: 0.6214 - val_loss: 1.1805 - val_accuracy: 0.5923
# Epoch 12/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0729 - accuracy: 0.6295 - val_loss: 1.1744 - val_accuracy: 0.5961
# Epoch 13/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0565 - accuracy: 0.6368 - val_loss: 1.1740 - val_accuracy: 0.5896
# Epoch 14/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0545 - accuracy: 0.6351 - val_loss: 1.1437 - val_accuracy: 0.6019
# Epoch 15/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0201 - accuracy: 0.6441 - val_loss: 1.1294 - val_accuracy: 0.6067
# Epoch 16/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0044 - accuracy: 0.6516 - val_loss: 1.1524 - val_accuracy: 0.6024
# Epoch 17/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0077 - accuracy: 0.6562 - val_loss: 1.1350 - val_accuracy: 0.6066
# Epoch 18/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9688 - accuracy: 0.6676 - val_loss: 1.1114 - val_accuracy: 0.6120
# Epoch 19/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9654 - accuracy: 0.6652 - val_loss: 1.0961 - val_accuracy: 0.6192
# Epoch 20/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9403 - accuracy: 0.6756 - val_loss: 1.1348 - val_accuracy: 0.6104
# Epoch 21/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.9494 - accuracy: 0.6716 - val_loss: 1.1009 - val_accuracy: 0.6167
# Epoch 22/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9319 - accuracy: 0.6781 - val_loss: 1.0829 - val_accuracy: 0.6254
# Epoch 23/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9158 - accuracy: 0.6841 - val_loss: 1.0802 - val_accuracy: 0.6291
# Epoch 24/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9114 - accuracy: 0.6895 - val_loss: 1.0961 - val_accuracy: 0.6199
# Epoch 25/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9014 - accuracy: 0.6914 - val_loss: 1.0902 - val_accuracy: 0.6241
# Epoch 26/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8841 - accuracy: 0.6939 - val_loss: 1.0775 - val_accuracy: 0.6316
# Epoch 27/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8672 - accuracy: 0.7034 - val_loss: 1.0830 - val_accuracy: 0.6224
# Epoch 28/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8701 - accuracy: 0.7001 - val_loss: 1.0791 - val_accuracy: 0.6292
# Epoch 29/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8762 - accuracy: 0.6994 - val_loss: 1.0647 - val_accuracy: 0.6354
# Epoch 30/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8481 - accuracy: 0.7096 - val_loss: 1.0935 - val_accuracy: 0.6236
# Epoch 31/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8437 - accuracy: 0.7100 - val_loss: 1.0905 - val_accuracy: 0.6229
# Epoch 32/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8364 - accuracy: 0.7132 - val_loss: 1.0728 - val_accuracy: 0.6312
# Epoch 33/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8265 - accuracy: 0.7167 - val_loss: 1.0630 - val_accuracy: 0.6301
# Epoch 34/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8317 - accuracy: 0.7130 - val_loss: 1.0577 - val_accuracy: 0.6389
# Epoch 35/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8198 - accuracy: 0.7176 - val_loss: 1.0849 - val_accuracy: 0.6293
# Epoch 36/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8023 - accuracy: 0.7237 - val_loss: 1.0466 - val_accuracy: 0.6429
# Epoch 37/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.7881 - accuracy: 0.7306 - val_loss: 1.0819 - val_accuracy: 0.6300
# Epoch 38/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8076 - accuracy: 0.7226 - val_loss: 1.0604 - val_accuracy: 0.6376
# Epoch 39/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.7724 - accuracy: 0.7348 - val_loss: 1.0598 - val_accuracy: 0.6365
# Epoch 40/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.7691 - accuracy: 0.7351 - val_loss: 1.0684 - val_accuracy: 0.6381
# Epoch 41/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.7606 - accuracy: 0.7394 - val_loss: 1.0932 - val_accuracy: 0.6298

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:00:35.803720

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 62.540

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
