# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidPuigV/Nuclio/blob/main/cnn_cifar10_tf2_v0_Working_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))    # 1 convo
model.add(ks.layers.MaxPooling2D((2, 2)))                 # maxpool

model.add(ks.layers.Flatten())                            # flatten despues convos
model.add(ks.layers.Dense(32, activation='relu'))         # capa dense

model.add(ks.layers.Dense(10, activation='softmax'))      # es clasificacion de 10

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                262176
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 263,402
# Trainable params: 263,402
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 3.1 Definimos callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
callback_earlystopping_val = EarlyStopping(monitor='val_loss', patience=5)
callback_earlystopping_acc = EarlyStopping(monitor='val_accuracy', patience=5)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0            # ya cambiamos el escalado a de 0 a 1 para tener numeros reales

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [ # picamos a mano las categorias que sacaremos
'airplane', # id 0
'automobile', # id 1
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck', # id 9
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, epochs=100, callbacks=[callback_earlystopping_val,callback_earlystopping_acc],
                    use_multiprocessing=False, batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 79/79 [==============================] - 4s 16ms/step - loss: 2.1955 - accuracy: 0.1980 - val_loss: 1.9073 - val_accuracy: 0.3172
# Epoch 2/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.8281 - accuracy: 0.3493 - val_loss: 1.6863 - val_accuracy: 0.3777
# Epoch 3/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.6307 - accuracy: 0.4112 - val_loss: 1.5403 - val_accuracy: 0.4433
# Epoch 4/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5140 - accuracy: 0.4607 - val_loss: 1.4897 - val_accuracy: 0.4645
# Epoch 5/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4407 - accuracy: 0.4848 - val_loss: 1.4313 - val_accuracy: 0.4904
# Epoch 6/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3831 - accuracy: 0.5080 - val_loss: 1.3892 - val_accuracy: 0.5012
# Epoch 7/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3417 - accuracy: 0.5189 - val_loss: 1.3834 - val_accuracy: 0.4977
# Epoch 8/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2985 - accuracy: 0.5357 - val_loss: 1.3113 - val_accuracy: 0.5412
# Epoch 9/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2692 - accuracy: 0.5450 - val_loss: 1.2958 - val_accuracy: 0.5502
# Epoch 10/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2313 - accuracy: 0.5609 - val_loss: 1.2699 - val_accuracy: 0.5538
# Epoch 11/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2139 - accuracy: 0.5684 - val_loss: 1.2585 - val_accuracy: 0.5573
# Epoch 12/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1928 - accuracy: 0.5742 - val_loss: 1.2309 - val_accuracy: 0.5732
# Epoch 13/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1709 - accuracy: 0.5818 - val_loss: 1.2649 - val_accuracy: 0.5569
# Epoch 14/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1603 - accuracy: 0.5833 - val_loss: 1.2460 - val_accuracy: 0.5620
# Epoch 15/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1438 - accuracy: 0.5958 - val_loss: 1.1933 - val_accuracy: 0.5829
# Epoch 16/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1183 - accuracy: 0.6014 - val_loss: 1.1831 - val_accuracy: 0.5862
# Epoch 17/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0927 - accuracy: 0.6089 - val_loss: 1.2081 - val_accuracy: 0.5696
# Epoch 18/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0954 - accuracy: 0.6074 - val_loss: 1.1723 - val_accuracy: 0.5930
# Epoch 19/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0732 - accuracy: 0.6135 - val_loss: 1.1568 - val_accuracy: 0.5990
# Epoch 20/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0554 - accuracy: 0.6229 - val_loss: 1.1663 - val_accuracy: 0.5870
# Epoch 21/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.0519 - accuracy: 0.6272 - val_loss: 1.1712 - val_accuracy: 0.5956
# Epoch 22/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0445 - accuracy: 0.6277 - val_loss: 1.1388 - val_accuracy: 0.5985
# Epoch 23/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0217 - accuracy: 0.6353 - val_loss: 1.1461 - val_accuracy: 0.6012
# Epoch 24/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0248 - accuracy: 0.6295 - val_loss: 1.1536 - val_accuracy: 0.5943
# Epoch 25/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0052 - accuracy: 0.6434 - val_loss: 1.1664 - val_accuracy: 0.5977
# Epoch 26/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0066 - accuracy: 0.6424 - val_loss: 1.2273 - val_accuracy: 0.5670
# Epoch 27/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0049 - accuracy: 0.6405 - val_loss: 1.1206 - val_accuracy: 0.6013
# Epoch 28/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9797 - accuracy: 0.6502 - val_loss: 1.1149 - val_accuracy: 0.6118
# Epoch 29/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.9688 - accuracy: 0.6549 - val_loss: 1.1318 - val_accuracy: 0.6023
# Epoch 30/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9584 - accuracy: 0.6592 - val_loss: 1.1090 - val_accuracy: 0.6114
# Epoch 31/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9543 - accuracy: 0.6621 - val_loss: 1.0894 - val_accuracy: 0.6174
# Epoch 32/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9421 - accuracy: 0.6638 - val_loss: 1.1185 - val_accuracy: 0.6120
# Epoch 33/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.9444 - accuracy: 0.6675 - val_loss: 1.1329 - val_accuracy: 0.6026
# Epoch 34/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9516 - accuracy: 0.6634 - val_loss: 1.0895 - val_accuracy: 0.6179
# Epoch 35/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9216 - accuracy: 0.6697 - val_loss: 1.0974 - val_accuracy: 0.6173
# Epoch 36/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9256 - accuracy: 0.6705 - val_loss: 1.1041 - val_accuracy: 0.6084

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:00:31.034649

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 60.350

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
